# %%
import os
from dotenv import load_dotenv
from pyprojroot import here

## INICIAR LANGSMITH Y API KEYS
dotenv_path = here() / ".env"
load_dotenv(dotenv_path=dotenv_path)
# Out:
# True

# %%
from langchain_community.document_loaders import PyMuPDFLoader

loader = PyMuPDFLoader("propuesta.pdf")

documents = loader.load()

documents[0]
# Out:
# Document(page_content=' \n \n \n \n \n \n \n \n \n \nCopyright © Todos los derechos reservados a Bantotal \n \n \n \n \n \n \n \n \n \n \n \nPROPUESTA ECONÓMICA \nPrórrogas de créditos cuotas flexibles - (247.204) \nPerú |Financiera Confianza \n \nClasificación del documento: \nPúblico:              ☐ \nPrivado:              ☐ \nConfidencial:     ☒ La información contenida en este documento es proporcionada con el único fin de presentar en la institución receptora, \nprohibiendo expresamente la publicación, divulgación y utilización de su  contenido a terceros. \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n', metadata={'source': 'propuesta.pdf', 'file_path': 'propuesta.pdf', 'page': 0, 'total_pages': 7, 'format': 'PDF 1.7', 'title': 'ACH - Módulo De Disputas Y Reportes', 'author': 'Noelia Araujo', 'subject': '233.958', 'keywords': 'Funcional', 'creator': 'Microsoft® Word para Microsoft 365', 'producer': 'Microsoft® Word para Microsoft 365', 'creationDate': "D:20240422115515-05'00'",
# ...

# %%
from langchain.text_splitter import CharacterTextSplitter
text_splitter = CharacterTextSplitter(chunk_size=800, chunk_overlap=0)
texts = text_splitter.split_documents(documents)
texts
# Out:
# [Document(page_content='Copyright © Todos los derechos reservados a Bantotal \n \n \n \n \n \n \n \n \n \n \n \nPROPUESTA ECONÓMICA \nPrórrogas de créditos cuotas flexibles - (247.204) \nPerú |Financiera Confianza \n \nClasificación del documento: \nPúblico:              ☐ \nPrivado:              ☐ \nConfidencial:     ☒ La información contenida en este documento es proporcionada con el único fin de presentar en la institución receptora, \nprohibiendo expresamente la publicación, divulgación y utilización de su  contenido a terceros.', metadata={'source': 'propuesta.pdf', 'file_path': 'propuesta.pdf', 'page': 0, 'total_pages': 7, 'format': 'PDF 1.7', 'title': 'ACH - Módulo De Disputas Y Reportes', 'author': 'Noelia Araujo', 'subject': '233.958', 'keywords': 'Funcional', 'creator': 'Microsoft® Word para Microsoft 365', 'producer': 'Microsoft® Word para Microsoft 365', 'creationDate': "D:20240422115515-05'00'", 'modDate': "D:20240422115515-05'00'", 'trapped': ''}),
# ...

# %%
from langchain.embeddings import AzureOpenAIEmbeddings
from langchain.vectorstores import Chroma
from langchain.chains import RetrievalQA
from langchain.llms import AzureOpenAI

#os.environ["OPENAI_API_KEY"] = 'c1a8271ab9b640cfb3d83f7df263c601'

embeddings = AzureOpenAIEmbeddings()
doc_search = Chroma.from_documents(texts, embeddings)
chain = RetrievalQA.from_chain_type(llm=AzureOpenAI(deployment_name="gpt-35-turbo-16k",
    temperature=0.0, retriever = doc_search.as_retriever()))
# Out:
# c:\Users\ncaytuiro\.conda\envs\chatpdf_API\Lib\site-packages\langchain_core\utils\utils.py:161: UserWarning: WARNING! retriever is not default parameter.
#                 retriever was transferred to model_kwargs.
#                 Please confirm that retriever is what you intended.
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# Cell In[43], line 10
#       8 embeddings = AzureOpenAIEmbeddings()
#       9 doc_search = Chroma.from_documents(texts, embeddings)
# ---> 10 chain = RetrievalQA.from_chain_type(llm=AzureOpenAI(deployment_name="gpt-35-turbo-16k",
#      11     temperature=0.0, retriever = doc_search.as_retriever()))
#
# File c:\Users\ncaytuiro\.conda\envs\chatpdf_API\Lib\site-packages\langchain\chains\retrieval_qa\base.py:109, in BaseRetrievalQA.from_chain_type(cls, llm, chain_type, chain_type_kwargs, **kwargs)
# ...

# %%
query = 'cual es el objetivo del requerimiento?'
chain.run(query)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[40], line 2
#       1 query = 'cual es el objetivo del requerimiento?'
# ----> 2 chain.run(query)
#
# File c:\Users\ncaytuiro\.conda\envs\chatpdf_API\Lib\site-packages\langchain_core\_api\deprecation.py:148, in deprecated.<locals>.deprecate.<locals>.warning_emitting_wrapper(*args, **kwargs)
#     146     warned = True
#     147     emit_warning()
# --> 148 return wrapped(*args, **kwargs)
#
# File c:\Users\ncaytuiro\.conda\envs\chatpdf_API\Lib\site-packages\langchain\chains\base.py:595, in Chain.run(self, callbacks, tags, metadata, *args, **kwargs)
#     593     if len(args) != 1:
#     594         raise ValueError("`run` supports only one positional argument.")
# --> 595     return self(args[0], callbacks=callbacks, tags=tags, metadata=metadata)[
#     596         _output_key
#     597     ]
# ...
